# %%
x=set()

# %%
x.add(1)

# %%
x
# Out:
# {1}

# %%
x.add(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8d1e6b317f1a> in <module>
# ----> 1 x.add(2,3)
#
# TypeError: add() takes exactly one argument (2 given)

# %%
x.add(3)

# %%
x
# Out:
# {1, 3}

# %%
list_1=[1,1,2,3,2,2,4,4,5,5]

# %%
set(list_1)
# Out:
# {1, 2, 3, 4, 5}

# %%
a='true'

# %%
a = 'true'
print(a)
# Out:
# true

# %%
1>2
# Out:
# False

# %%
3<4
# Out:
# True

# %%
b=none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bc92192b5522> in <module>
# ----> 1 b=none
#
# NameError: name 'none' is not defined

# %%
b='none'

# %%
print(b)
# Out:
# none
